# %%
import pandas as pd

# %%
df1= pd.read_parquet('Predictors/sm-calls_summarized_post2018.parquet', engine='fastparquet')
df1.head()
# Out:
#    transcriptid   permno mostimportantdateutc  mostimportanttimeutc  \
# 0     1665720.0  80191.0           2019-02-21           50400000000
# 1     1927283.0  80191.0           2020-02-20           50400000000
# 2     2215483.0  80191.0           2021-02-18           50400000000
# 3     2740261.0  80191.0           2023-02-16           50400000000
# 4     1651047.0  79323.0           2019-02-06           52200000000
#
#    audiolengthsec                                               text  \
# 0          3844.0  Good day, ladies and gentlemen, and welcome to...
# 1          3453.0  Ladies and gentlemen, thank you for standing b...
# 2          3674.0  Ladies and gentlemen, thank you for standing b...
# 3          1833.0  Ladies and gentlemen, welcome to the Albemarle...
# 4          3831.0  Good day, ladies and gentlemen, and welcome to...
#
#    text_length  word_count  companyid               companyname  \
# 0        51197        8924    18671.0     Albemarle Corporation
# ...

# %%
df2= pd.read_parquet('merged_data.parquet', engine='fastparquet')
df2.head()
# Out:
#       date                                               text  \
# 0  2020-11  J&J Snack Foods reported Q4 2022 revenues down...
# 1  2021-11  J&J Snack Foods reported strong Q4 2021 result...
# 2  2023-11  J&J Snack Foods reported robust Q4 2023 and FY...
# 3  2021-10  Plexus reported Q4 2021 GAAP EPS of $1.16 and ...
# 4  2022-10  Plexus Corp. reported Q4 2022 revenue of $1.12...
#
#                             industry  ret_3M_shifted
# 0      Food & Beverage Manufacturing       -0.007357
# 1      Food & Beverage Manufacturing       -0.048821
# 2      Food & Beverage Manufacturing        0.001644
# 3  Electronic & Electrical Equipment        0.050955
# 4  Electronic & Electrical Equipment       -0.001042

# %%
df3 = pd.read_parquet('Predictors/sm-calls_with_connectors.parquet', engine='fastparquet')
df3.head()
# Out:
#    transcriptid   permno mostimportantdateutc mostimportanttimeutc  \
# 0       18033.0  80191.0           2008-01-29      0 days 14:00:00
# 1       15710.0  80191.0           2009-01-27      0 days 15:00:00
# 2       46982.0  80191.0           2010-01-26      0 days 15:00:00
# 3       95321.0  80191.0           2011-01-25      0 days 15:00:00
# 4      210122.0  80191.0           2012-01-24      0 days 13:00:00
#
#    audiolengthsec                                               text  \
# 0             NaN  Good day, ladies and gentlemen, and welcome to...
# 1             NaN  Good day ladies and gentlemen, and welcome to ...
# 2          4740.0  Good day, ladies and gentlemen, and welcome to...
# 3          3600.0  Good day, ladies and gentlemen, and welcome to...
# 4          3967.0  Good day, ladies and gentlemen, and welcome to...
#
#    text_length  word_count  companyid            companyname  \
# 0        63457       10905    18671.0  Albemarle Corporation
# ...

# %%
df3 = df3[[df3['mostimportantdateutc'] >= '2018-01-01']]
df3.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df3 = df3[[df3['mostimportantdateutc'] >= '2018-01-01']]
#       2 df3.head()
#
# File /opt/homebrew/anaconda3/envs/myenv_mlfin/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/anaconda3/envs/myenv_mlfin/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
